# %% [markdown]
# # Intro to Financial Technologies

# %% [markdown]
# # Map

# %% [markdown]
# 1. Information Governance in Banking
# 2. Adoption of Financial Technologies

# %% [markdown]
# # 1. Information Governance in Banking

# %% [markdown]
# ## Origin Story

# %% [markdown]
# **Economics goal** $\to$ efficiently allocate risk and capital
#
# **Main barrier** $\to$ information frictions

# %% [markdown]
# <!-- <center><img src="figures/information-no-banks.png" width="700"><center> -->
# :::{figure} figures/information-no-banks.png
# :width: 700px
# :align: center
# :::

# %% [markdown]
# ## The Intermediation Solution

# %% [markdown]
# **Banks' fundamental value proposition** $\to$ solver of information frictions

# %% [markdown]
# <!-- <center><img src="figures/information-banks.jpg" width="700"><center> -->
# :::{figure} figures/information-banks.jpg
# :width: 700px
# :align: center
# :::

# %% [markdown]
# ## Information frictions

# %% [markdown]
# ### Asymmetric information in credit
#
# `screening/monitoring problem` to prevent **adverse selection** and **moral hazard**
#
# - Better information **lowers transaction costs**, but creates **information rents** (Boot, 2000)
#     - Banks **produce information** to improve their services (e.g., monitoring technology)
#     - Banks **hoard information** to capture surplus and limit competition
#
# **Implications**
#
# - **Rate of information production** (De Marco and Petriconi, 2024)
# - **Consumer welfare** (prices, lockins, etc.) (Schenone, 2010)
# - **Rationing** and de-risking (Holmstrom & Tirole, 1997)
# - **Barriers to entry** (Bofondi and Gobbi, 2006)

# %% [markdown]
# ### Incomplete information in deposit
# `forecasting problem` to determine **future states** of the world
#
# - Banks create liquidity through **maturity transformation**
# - Efficiency and stability relies on **information** about the future: withdrawals are highly sensitive to **perceptions of solvency**.
#
# **Implications**
#
# - **Bank runs** and **deposit insurance** (Diamond and Dybvig, 1983)
# - **Lender-of-last-resort** (Diamond and Rajan, 2005)
# - **Contagion** and **systemic risk** (Allen and Gale, 2000)
# - **Bankruptcy cost**: Bank failures destroy accumulated information capital (Bernanke, 1983)

# %% [markdown]
# ### Confidential information in payments
# `privacy problem` to match on on sensitive information
#
# - Information technologies exhibit strong **economies of scale and scope**.
# - In presence of **sensitive information**, verification and matching services are prone to large **network effects**.
#
# **Implications**
#
# - Market power (Rochet and Tirole, 2003)
# - Trust and digital adoption (Lee, McAndrews and Wang, 2020)
# - Concentrated markets (Tirole, 2015)

# %% [markdown]
# ### Special Case: Illicit Activity (AML/CFT)
# Superior information capacity bestows special public duties on banks
#
# - **Monitoring delegation**: governments rely on bank data and reporting of **suspicious activities**.
#     - **Screening**: Know-Your-Customer
#     - **Monitoring**: Detect illicit transactions in real time.
#     - **Safeguarding**: Balance confidentiality with mandatory disclosure obligations to authorities.
#
# **Implications**
#
#   - **Compliance cost** with limited private benefits
#   - Potential exclusion effects (**de-risking**)

# %% [markdown]
# ### Summary table
#
# | Type            | Problem                     | Economic Issue                   | Example   | Market Implications |
# |-----------------|-----------------------------|----------------------------------|-----------|---------------------|
# | **Asymmetric**  | Screening <br> Monitoring   | Adverse selection <br> Moral hazard | Credit    | ↓ rationing <br> ↑ information rents |
# | **Incomplete**  | Forecasting                 | Uncertainty                      | Deposit   | ↓ liquidity mismatch <br> ↑ instability (bank runs) |
# | **Confidential**| Privacy                     | Matching on sensitive data       | Payments  | ↓ search & verification frictions <br> ↑ market power (trust, network effects) |

# %% [markdown]
# <b><u>Special Case</u></b>: **Financial crime (AML/CFT)**
#
# - Bank's **superior information capacity** bestows special **public duties**: identifying, reporting, monitoring of **suspicious activities**
# -  **Compliance cost** with limited private benefits with potential exclusion effects (**de-risking**)

# %% [markdown]
# ## Information Governance Approach

# %% [markdown]
# <center><b>Banking services are contracts whose scope and values are structurally bounded by specific information sets</b></center>
#
#
# Who can <b>produce, access and control information</b> defines <b>how services can be offered</b> - and ultimately <b>shapes how well markets can function</b></center>
#
# $\to$ <b>Information Governance</b>

# %% [markdown]
# ## Digitalization

# %% [markdown]
# The systematic **conversion of financial information** into **data**:
#
# - **codified**
# - **verifiable**
# - **machine-readible data**
#
# From **soft**, **relational knowledge** $\rightarrow$ **hard** and **transferable inputs** for economic exchange and supervision.

# %% [markdown]
# $\to$<b>Digitalisation reshapes Information Governance</b>

# %% [markdown]
# ## Digital Technologies & FinTech

# %% [markdown]
# Fundamentally: technologies are about **reducing cost**.
#
# <center><b>Digital technologies reduce information costs.</b></center>
#
# - **Artificial Intelligence**
# - **Platforms**
# - **Distributed Ledger Technology (DLT)**
# - **Cloud / APIs / etc.**
#
# When applied to financial functions such as lending, trading, or payments, these digital technologies give rise to **financial technologies (FinTech)** — innovations that reshape how financial services are produced and delivered.
#
# <center><b>FinTech = Digital Technology + Financial Function/Application</b></center>

# %% [markdown]
# ### Artificial Intelligence

# %% [markdown]
# **Modern AI** (Machine Learning) is about **reducing the cost of `prediction`**. (Agrawal, Gans & Goldfarb, 2022)
#
# `prediction` in Banking: **credit**, **liquidity management**, etc. (`forecasting`, `monitoring`, `screening` )

# %% [markdown]
# **Key features**
#
# - **Data dependency**
#   Quantity & quality determine predictive power.
# - **Application limits**
#     Not all problems are prediction problems (reasoning, causality, logic).
#     Not all prediction problems are ML problems (data scarcity $\to$ COVID-19).

# %% [markdown]
# ### Platforms

# %% [markdown]
# **Platforms** are digital infrastructures that **reduce the cost of `search` and `matching`** leveraging **private (often sensitive) data**. (Bergemann and Bonatti, 2024)
#
# `search` and `matching` in Banking: **Payments**, **Investments**
#
# **Key features**
#
# - **Network effects and data**
#   More users $\to$ more data $\to$ better services $\to$ attracts more users. (Hagiu and Wright, 2023)
# - **Multi-sidedness**
#   Different users, different prices: cross-subsidize and free services. (Rochet and Tirole, 2006)

# %% [markdown]
# ### Distributed Ledger Technology (DLT)

# %% [markdown]
# <div style="border-left: 5px solid #000000; padding: 0.75em; background-color: #f9f9f9; border-radius: 6px;">
# <b><u>Note:</u></b> <b>Cryptography</b> is about <b>verifiability without observability</b>: <i>Ownership, actions or states can be publically proven without revealing underlying information.</i>
# </div>

# %% [markdown]
# **DLT** allow to **reduce the cost of verification** in public ledgers leveraging **crypto solution** and **mechanism design**. (Catalini and Gans, 2018)
#
# **`Verification` in Banking**: **Payments**, **Contingent Contracting**
#
# **Key features**
#
# - **Elimination of confidential information**
#     Shifts the structure of information — what is public, private, and verifiable. (Roukny, 2022)
#     Removes the need for third party safeguarding
#     Prevents further auditing (identification, monitoring, etc.)
# - **Decentralised Finance**
#     Increase in public ledgers expands self-executing contracting spaces (**smart contracts**)

# %% [markdown]
# ### Summary Table
#
# | Technology | Information Cost | How | Banking | Key Features |
# |------------|--------------|------------|------------|--------------|
# | **Modern AI** | `Prediction` <br> (Agrawal, Gans & Goldfarb, 2022)| Statistical learning | Credit <br>Liquidity management | **Data <br> Computation**|
# | **Digital Platforms** | `Searching & matching` <br> (Bergemann & Bonatti, 2024) | Private/sensitive data | Payments<br> Investments | **Network effects <br> Multi-sidedness**|
# | **DLT** | `Public verification` <br> (Catalini & Gans, 2018) | Cryptography <br> Mechanism design | Payments <br> Contingent contracting | **Decentralisation<br> Smart contracting**|

# %% [markdown]
# ## A New Digital Information Governance

# %% [markdown]
# ### AI & Platforms
#
# 1. Value of **alternative data** (e.g., digital footprint, device metadata, geolocalisation, webscraping etc.)
#     - &uarr; the relevant information space
#     - &uarr; **entry** of new actors with new data access (**fintech, bigtech**)
#
#
# 2. More power in **signal extraction** from **traditional financial data**
#     - &uarr; efficiency of banking services
#     - &uarr; intensity of incumbent competition/innovation
#     - ~ **entry limited** by in-house information production
#
# ### DLT
#
# 1. **Verification** without **confidential information**
#     - &darr; **intermediation rent**
#     - &darr; **auditing power** on private information
# 2. Expansion of **public information space**
#    - &uarr; **contestability, interoperability & innovation**

# %% [markdown]
# # 2. Adoption of Financial Technologies

# %% [markdown]
# ## Banking

# %% [markdown]
# 1. **Intensive margin**: AI adoption and computing power for inhouse data
# 2. **Extensive margin**: *Platformisation* by expanding data collection to alternative data
# 3. **Crypto resistance** so far (regulation, compliance, disintermediation threat)

# %% [markdown]
# <center><b>Adoption of AI and data-related activities<br>Limited adoption of DLT and applications</b></center>
#
# <!-- <center><img src="figures/eba_bank_tech_adoption.png" width="700"></center> -->
# :::{figure} figures/eba_bank_tech_adoption.png
# :width: 700px
# :align: center
# :::
# <center>EBA - Risk Assessment Questionnaire - Spring 2025</center>

# %% [markdown]
# <center><b>Main use of AI<br>Monitoring, Screening and AML/Fraud</b></center>
# <!-- <center><img src="figures/eba_bank_ai_application.png" width="700"><center> -->
#
# :::{figure} figures/eba_bank_ai_application.png
# :width: 700px
# :align: center
# :::
# <center>EBA - Risk Assessment Questionnaire - Spring 2025</center>

# %% [markdown]
# ### Adoption at Intensive Margin
# <center><b>Transition to superior prediction technologies: unequal effects across the population</b></center>
#
# <!-- <center><img src="figures/fuster_ai.jpg" width="500"><center> -->
# :::{figure} figures/fuster_ai.png
# :width: 600px
# :align: center
# :::
#
# <center>Fuster, A., Goldsmith‐Pinkham, P., Ramadorai, T., & Walther, A. (2022). Predictably unequal? The effects of machine learning on credit markets. The Journal of Finance, 77(1), 5-47.</center>

# %% [markdown]
# ### Extensive Margin
# <center><b> Inlcuding alternative data: 1st order improvement in prediction power</b></center>
# <!-- <center><img src="figures/berg_ai.png" width="600"><center> -->
#
# :::{figure} figures/berg_ai.png
# :width: 600px
# :align: center
# :::
#
# <center>Berg, T., Burg, V., Gombović, A., & Puri, M. (2020). On the rise of fintechs: Credit scoring using digital footprints. The Review of Financial Studies, 33(7), 2845-2897.</center>

# %% [markdown]
# ### Platformisation
# **The rise of Super-Apps**: transition to **multi-sided platform**
#
#
# <!-- <center><img src="figures/kbc.jpeg" width="200"><center> -->
# :::{figure} figures/kbc.jpeg
# :width: 200px
# :align: center
# :::
# <center>2024 Award of the Best Banking App in the World (SIA Partners)</center>

# %% [markdown]
# ## The New Digital Landscape
# ### Enter Fintech and Bigtech companies
#
# **FinTech** = technology + financial services
#
# **BigTech** = established tech platform firms expanding into finance (Amazon, Alphabet, Meta, etc.)

# %% [markdown]
# ### Fintech x Bigtech in credit
# <center><b> Continuous growth from low base<br> Main penetration from China</b></center>

# %% [markdown]
# <!-- <center><img src="figures/fintech_bigtech_credit.jpg" width="400"><center> -->
# :::{figure} figures/fintech_bigtech_credit.jpg
# :width: 600px
# :align: center
# :::
#
# <center>Cecchetti, S., Beck, T., Grothe, M., Kemp, M., Pelizzon, L., & Serrano, A. S. (2022). Will video kill the radio star?–Digitalisation and the future of banking. Reports of the Advisory Scientific Committee, 12.</center>

# %% [markdown]
# ### Fintech in EU
# <center><b> Exponential growth over the past decade<br> Mainly credit, payment, crowdfunding and back-end processes</b></center>
# <!-- <center><img src="figures/fintech_HQ.png" width="800"><center> -->
#
# :::{figure} figures/fintech_HQ.png
# :width: 700px
# :align: center
# :::
# <center>Cambridge Fintech Ecosystem Atlas - Cambridge Centre for Alternative Finance - Own calculation</center>

# %% [markdown]
# ### Bigtech in EU
# <center><b>Main penetration point: Payments</b></center>
#
# <!-- <center><img src="figures/bigtech_EU_licenses.jpg" width="700"><center> -->
# :::{figure} figures/bigtech_EU_licenses.jpg
# :width: 700px
# :align: center
# :::
#
# <center>Joint-ESA Report on 2023 stocktaking of BigTech direct financial services provision in the EU</center>

# %% [markdown]
# ## Digital Impact on Business Models

# %% [markdown]
# Change in information governance implies a <b>modularisation of banking</b>.
#
# $\to$ Each service becomes a module that can be provided independently (Boot at el., 2021).

# %% [markdown]
# ### 1. **Unbundling of banking services**
#
# Banks face competition at each segment against heterogeneous agents
#
# - **Payments**: `PayPal`, `Wise`
# - **Lending**: `Funding Circle`, `LendingClub`
# - **Deposits**: `USDT`, `USDC` (stablecoins)

# %% [markdown]
# ### 2. **Re-bundling of banking services** (w/ or w/o other services)
#
# Fintech/Bigtech build their offerings up
#
# - **Payments $\to$ credit**: `Cash App`
# - **E-commerce platforms $\to$ finance**: `Amazon Lending`, `Shopify Capital`
# - **All-in-one app**: `Alipay`, `WeChat Pay`, `Revolut`
# - **Telecom/BigTech cross-bundles**: `Orange Bank` (bundling mobile subscription with banking)

# %% [markdown]
# ## Digital Impact on Customer Segments: Niche vs Core

# %% [markdown]
# <center>Digitalisation doesn’t erode banks uniformly</center>

# %% [markdown]
# ### 1. **Niches**: Entry where banks underserve (high costs or weak offerings)
# - **Remittances**: `Wise` , `Remitly`
# - **SME services**: `Tide`, `Holvi`, `Qonto`
# - **Gig-economy**: `Chime`, `Monese`
# - **Buy-Now-Pay-Later**: `Klarna`, `Affirm`, `Apple Pay Later`, `CashApp`
# - **Outliers**: `Suitsme`
#   "*When banks say no, we say yes*"
#   "*Struggling to open an account after leaving prision? It’s time to try an account that suits you!*"

# %% [markdown]
# ### 2. **Core**: Target banks’ primary revenue pools.
#
# - **Payments**: `PayPal`, `Adyen`, `Apple Pay`, `Alipay`
# - **Deposits**: `USDT`, `USDC`
# - **Bank accounts**: `Revolut`, `N26`
# - **Credit**: `Amazon Lending`, `Shopify Capital`
# - **Mortgages**: `Rocket Mortgage`
# - **Asset management**: `Robinhood`, `Trade Republic`

# %% [markdown]
# ## Digitalisation Shows Promises and Pitfalls

# %% [markdown]
# ### **Increased information value**
# - &darr; **information barriers**
#     - extensive margin: &uarr; **new entry**
#     - intensive margin: &uarr; **efficiency gains**
# - &uarr; **innovation** and **adoption**
#
# ### **But… breaking down banks’ integrated services may**
# - Eliminate prior **synergies**
# - Create **new costs** (e.g. double margins)
# - Introduce **new sources of market power** (see later)

# %% [markdown]
# ## Open question
# <center><b>Banks and Fintech/Bigtech <br> Complementarity vs. Substitution?</b></center>
#
# | Type     | References |
# |--------------|------------|
# | **Complement** |- Erel, I., & Liebersohn, J. (2022). *Can FinTech reduce disparities in access to finance? Evidence from the Paycheck Protection Program.* Journal of Financial Economics, 146(1), 90-118.<br>- Di Maggio, M., Ratnadiwakara, D., & Carmichael, D. (2022). *Invisible primes: Fintech lending with alternative data* (No. w29840). National Bureau of Economic Research.<br>- Gambacorta, L., Cornelli, G., Frost, J., Rau, R., Wardrop, R., & Ziegler, T. (2020). *Fintech and big tech credit: a new database* (No. 15357). CEPR Discussion Papers. |
# | **Substitute** | - Naceur, S. B., Candelon, B., Elekdag, S., & Emrullahu, D. (2023). *Is FinTech Eating the Bank’s Lunch?* Journal of International Financial Management & Accounting.<br>- Eça, A., Ferreira, M. A., Prado, M. P., & Rizzo, A. E. (2022). *The real effects of fintech lending on SMEs: Evidence from loan applications.* ECB Working Paper Series No 2639.<br>- Tang, H. (2019). *Peer-to-peer lenders versus banks: substitutes or complements?* The Review of Financial Studies, 32(5), 1900-1938.<br>Buchak, G., Matvos, G., Piskorski, T., & Seru, A. (2018). *Fintech, Regulatory Arbitrage, and the Rise of Shadow Banks.* Journal of Financial Economics, 130, 453-483. |
# | **Both** | - Di Maggio, M., & Yao, V. (2021). *Fintech borrowers: Lax screening or cream-skimming?* The Review of Financial Studies, 34(10), 4565-4618. |

# %% [markdown]
# <center><b><u>Vertical and horizontal relations</u><br>Threat: retail banking and payments<br>Opportunity: commercial banking and trading services</b></center>
#
# <!-- <center><img src="figures/esrb_fintech_threat.png" width="800"><center> -->
# :::{figure} figures/esrb_fintech_threat.png
# :width: 700px
# :align: center
# :::
#
# <center>Cecchetti, S., Beck, T., Grothe, M., Kemp, M., Pelizzon, L., & Serrano, A. S. (2022). Will video kill the radio star?–Digitalisation and the future of banking. Reports of the Advisory Scientific Committee, 12.</center>

# %% [markdown]
# <center><b><u>Vertical relations</u> <br> Bank x Bigtech for advertisement & Bank x Fintech for white labelling<br> Limited distribution agreements</b></center>
#
# <!-- <center><img src="figures/eba_bank_coop.png" width="700"><center> -->
# :::{figure} figures/eba_bank_coop.png
# :width: 700px
# :align: center
# :::
#
# <center>EBA - Risk Assessment Questionnaire - Spring 2025</center>

# %% [markdown]
# <center><b><u>Banks and Fintech </u><br> Cooperation through services, consulting, (low) partnerships<br> Limited acquisition, joint venture plans</b></center>
#
# <!-- <center><img src="figures/ecb_coop.png" width="600"><center> -->
# :::{figure} figures/ecb_coop.png
# :width: 700px
# :align: center
# :::
#
# <center>ECB - Take-aways from the horizontal assessment of the survey on digital transformation and the use of fintech - February 2023</center>

# %% [markdown]
# <center><b><u>Possible equilibrium</u></b></center>
#
# <!-- <center><img src="figures/barbel.png" width="1000"><center> -->
# :::{figure} figures/barbel.png
# :width: 700px
# :align: center
# :::
#
# <center>Feyen, E., Frost, J., Gambacorta, L., Natarajan, H., & Saal, M. (2021). Fintech and the digital transformation of financial services: implications for market structure and public policy. BIS papers.</center>
